# %%
import pandas as pd
import numpy as np

# %%
sf_crime = pd.read_csv("../clean_data/sf_crime.csv")
sf_crime = sf_crime.drop(["Unnamed: 0"], axis = 1)
sf_crime
# Out:
#              city  population  violent crime  \
# 0   San Francisco    764693.0         5323.0
# 1   San Francisco    881514.0         4796.0
# 2   San Francisco    886007.0         5933.0
# 3   San Francisco    889282.0         6144.0
# 4   San Francisco    881255.0         6301.0
# 5   San Francisco    871155.0         6190.0
# 6   San Francisco    863782.0         6710.0
# 7   San Francisco    850294.0         6761.0
# 8   San Francisco    833863.0         7064.0
# 9   San Francisco    820363.0         5777.0
# 10  San Francisco    814701.0         5374.0
# 11  San Francisco    818594.0         5747.0
# 12  San Francisco    809755.0         5957.0
# 13  San Francisco    798144.0         6744.0
# 14  San Francisco    733799.0         6414.0
# 15  San Francisco    746085.0         6533.0
# 16  San Francisco    749172.0         5985.0
# 17  San Francisco    760353.0         5757.0
# 18  San Francisco    772065.0         5725.0
#
# ...

# %%
unemployment_df = pd.read_csv("../clean_data/sf_unemployment.csv")
unemployment_df = unemployment_df.drop(["Unnamed: 0"], axis = 1)
unemployment_df
# Out:
#     year  unemployment average
# 0   2003          29184.416667
# 1   2004          24197.416667
# 2   2005          20554.416667
# 3   2006          17462.666667
# 4   2007          18189.416667
# 5   2008          24093.333333
# 6   2009          41801.583333
# 7   2010          44207.750000
# 8   2011          40366.250000
# 9   2012          34978.333333
# 10  2013          28430.250000
# 11  2014          23335.666667
# 12  2015          19844.500000
# 13  2016          18344.416667
# 14  2017          16606.000000
# 15  2018          13639.416667
# 16  2019          12865.083333
# 17  2020          44465.583333
# 18  2021          27827.083333
# 19  2022          14599.833333
